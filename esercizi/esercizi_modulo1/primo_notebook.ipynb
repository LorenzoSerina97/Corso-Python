# %% [markdown]
# # Il Mio Primo Notebook Python
#
# Questo notebook esplora i calcoli base e i cicli.

# %%
# Cella Codice #1: Calcola l'area di un rettangolo
larghezza = 5
altezza = 10
area = larghezza * altezza
print(f"L'area del rettangolo è: {area}")
# Out:
# L'area del rettangolo è: 50

# %% [markdown]
# ## Formula dell'Area
#
# L'area di un rettangolo si calcola con:
# **Area = larghezza × altezza**

# %%
# Cella Codice #2: Crea una lista di numeri e calcola la somma
numeri = [10, 20, 30, 40, 50]
somma_totale = sum(numeri)
print(f"La somma è: {somma_totale}")

# %%
# Cella Codice #3: Usa un ciclo for per stampare i numeri pari da 0 a 10
print("Numeri pari da 0 a 10:")
for numero in range(0, 11):
    if numero % 2 == 0:
        print(numero)

# %% [markdown]
# ## Sfida Bonus: Visualizza i Dati
#
# Aggiungiamo un grafico per visualizzare i dati!

# %%
# Sfida Bonus: Visualizzazione con matplotlib
import matplotlib.pyplot as plt

# Dati di esempio
mesi = ["Gen", "Feb", "Mar", "Apr", "Mag"]
vendite = [120, 150, 180, 130, 200]

# Crea il grafico
plt.bar(mesi, vendite, color='skyblue')
plt.title("Vendite Mensili")
plt.xlabel("Mese")
plt.ylabel("Vendite")
plt.show()
